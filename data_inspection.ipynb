# %%
import pandas as pd

# %% [markdown]
# # Data Inspection

# %% [markdown]
# The data provided for this project in the format of CSV files contains denormalized data representing different aspects of an electrical company's operations. This hypothetical company provided electricity distribution and maintenace services.
#
# Files provided:
# - Bills_raw
# - clients_raw
# - connections_raw
# - service_orders_raw
# - technicians_raw
#
# These files contain denormalized and partially redundant information that needs to be cleaned, structured, and integrated into a consistent relational database.

# %% [markdown]
# ## Bills_raw

# %%
df_bills = pd.read_csv ("./raw_data/bills_raw.csv")
# First 5 rows of data
df_bills.head()
# Out:
#   bill_id connection_id client_id     client_name period_start  period_end  \
# 0   B0001        CN1768      C040  Isabela Simões   2025-02-18  2025-03-20
# 1   B0002        CN1252      C074    Sofia Campos   2025-05-18  2025-06-17
# 2   B0003        CN1226      C197    Luana Soares   2025-09-24  2025-10-24
# 3   B0004        CN1821      C405    Edgar Vieira   2025-04-15  2025-05-15
# 4   B0005        CN1856      C429   Emma Baptista   2024-12-28  2025-01-27
#
#    kwh_used  amount  issue_date payment_date
# 0       855  129.28  2025-03-22   2025-03-31
# 1       890   59.29  2025-06-19   2025-06-27
# 2       445  175.68  2025-10-26   2025-11-09
# 3       800  155.23  2025-05-17   2025-06-04
# 4       734  158.69  2025-01-29   2025-02-11

# %%
# Data Type Information
df_bills.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3500 entries, 0 to 3499
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   bill_id        3500 non-null   object
#  1   connection_id  3500 non-null   object
#  2   client_id      3500 non-null   object
#  3   client_name    3500 non-null   object
#  4   period_start   3500 non-null   object
#  5   period_end     3500 non-null   object
#  6   kwh_used       3500 non-null   int64
#  7   amount         3500 non-null   float64
#  8   issue_date     3500 non-null   object
#  9   payment_date   3500 non-null   object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 273.6+ KB

# %% [markdown]
# ## Clients_raw

# %%
df_clients = pd.read_csv ("./raw_data/clients_raw.csv")
# First 5 rows of data
df_clients.head()
# Out:
#   client_id       client_name                       email            phone  \
# 0      C162      Inês Almeida   mariopinheiro@example.org      913 009 792
# 1      C594    Iara Fernandes       pteixeira@example.org  (351) 928945590
# 2      C527        Ivan Faria  baptistamateus@example.net        230748207
# 3      C575   Guilherme Alves        hribeiro@example.org    +351920952294
# 4      C108  Carlota Carneiro          frocha@example.net    +351912895392
#
#                                              address  \
# 0  R. Ema Baptista, 195, 5281-273 Vila Nova de Sa...
# 1        Av Amaral, 59, 4894-204 Póvoa de Santa Iria
# 2           Avenida de Baptista, 49, 0655-782 Chaves
# 3           Rua Tavares, 75, 0399-529 Alcácer do Sal
# 4               R. de Castro, 709, 2959-391 Estremoz
#
#                             property_address connection_id        status
# 0  Alameda de Guerreiro, 61, 9885-217 Pinhel        CN1000  Disconnected
# ...

# %%
# Data Type Information
df_clients.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   client_id         100 non-null    object
#  1   client_name       100 non-null    object
#  2   email             100 non-null    object
#  3   phone             100 non-null    object
#  4   address           100 non-null    object
#  5   property_address  100 non-null    object
#  6   connection_id     100 non-null    object
#  7   status            100 non-null    object
# dtypes: object(8)
# memory usage: 6.4+ KB

# %% [markdown]
# ## Connections_raw

# %%
df_connections = pd.read_csv ("./raw_data/connections_raw.csv")
# First 5 rows of data
df_connections.head()
# Out:
#   connection_id client_id       client_name  \
# 0        CN1000      C162      Inês Almeida
# 1        CN1001      C594    Iara Fernandes
# 2        CN1002      C527        Ivan Faria
# 3        CN1003      C575   Guilherme Alves
# 4        CN1004      C108  Carlota Carneiro
#
#                             property_address                     city  \
# 0  Alameda de Guerreiro, 61, 9885-217 Pinhel                   Vizela
# 1  Avenida Guerreiro, 43, 9900-094 Rio Tinto    Reguengos de Monsaraz
# 2     R. dos Estorninhos, 95, 5854-551 Elvas                 Almeirim
# 3   Rua Tavares, 75, 0399-529 Alcácer do Sal  0399-529 Alcácer do Sal
# 4       R. de Castro, 709, 2959-391 Estremoz        2959-391 Estremoz
#
#   connection_type install_date meter_serial        status technician_id  \
# 0    Single-phase   2024-06-04      MTR1000  Disconnected          T116
# 1    Single-phase   2024-05-19      MTR1001     Suspended          T020
# ...

# %%
# Data Type Information
df_connections.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   connection_id     1200 non-null   object
#  1   client_id         1200 non-null   object
#  2   client_name       1200 non-null   object
#  3   property_address  1200 non-null   object
#  4   city              1200 non-null   object
#  5   connection_type   1200 non-null   object
#  6   install_date      1200 non-null   object
#  7   meter_serial      1200 non-null   object
#  8   status            1200 non-null   object
#  9   technician_id     1200 non-null   object
#  10  technician_name   1200 non-null   object
# dtypes: object(11)
# memory usage: 103.3+ KB

# %% [markdown]
# ## Serivce_Orders_raw

# %%
df_service_orders = pd.read_csv ("./raw_data/service_orders_raw.csv")
# First 5 rows of data
df_service_orders.head()
# Out:
#   service_order_id connection_id client_id          client_name technician_id  \
# 0           SO0001        CN1948      C341        Rafael Macedo          T083
# 1           SO0002        CN1199      C475    Andreia Rodrigues          T095
# 2           SO0003        CN1630      C002       Sandro Fonseca          T101
# 3           SO0004        CN1222      C531  Maria de Figueiredo          T069
# 4           SO0005        CN1670      C309     Lisandro Moreira          T058
#
#           technician_name   service_type  start_date    end_date  \
# 0              Noa Simões     Inspection  2025-02-20  2025-03-01
# 1        Nuno Melo-Garcia  Disconnection  2025-06-17  2025-07-20
# 2            Andreia Cruz  Disconnection  2025-08-05  2025-08-25
# 3             Eva Fonseca    Maintenance  2025-04-25  2025-08-14
# 4  Henrique Santos-Amorim  Disconnection  2024-10-29  2025-07-19
#
#                                     notes
# 0  Underground cable inspection completed
# ...

# %%
# Data Type Information
df_service_orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   service_order_id  2500 non-null   object
#  1   connection_id     2500 non-null   object
#  2   client_id         2500 non-null   object
#  3   client_name       2500 non-null   object
#  4   technician_id     2500 non-null   object
#  5   technician_name   2500 non-null   object
#  6   service_type      2500 non-null   object
#  7   start_date        2500 non-null   object
#  8   end_date          2500 non-null   object
#  9   notes             2500 non-null   object
# dtypes: object(10)
# memory usage: 195.4+ KB

# %% [markdown]
# ## Technicians_raw

# %%
df_technicians = pd.read_csv ("./raw_data/technicians_raw.csv")
# First 5 rows of data
df_technicians.head()
# Out:
#   technician_id  technician_name                       email  \
# 0          T001  Letícia Machado  marcossimoes@rodrigues.com
# 1          T002      Manuel Lima   santosgabriela@araujo.net
# 2          T003    Tatiana Nunes        miguelreis@jesus.com
# 3          T004   Mafalda Araújo         lleite@ferreira.org
# 4          T005    Salomé Araújo             npires@melo.com
#
#                phone          center   region                skills
# 0          922038862    Porto Center    Porto  Installation, Repair
# 1  (351) 934 530 693  Coimbra Center  Coimbra            Inspection
# 2  (351) 931 816 778   Lisboa Center   Lisboa            Inspection
# 3      +351964460838    Porto Center    Porto  Installation, Repair
# 4      +351913912878     Faro Center     Faro  Installation, Repair

# %%
# Data Type Information
df_technicians.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   technician_id    120 non-null    object
#  1   technician_name  120 non-null    object
#  2   email            120 non-null    object
#  3   phone            120 non-null    object
#  4   center           120 non-null    object
#  5   region           120 non-null    object
#  6   skills           120 non-null    object
# dtypes: object(7)
# memory usage: 6.7+ KB
